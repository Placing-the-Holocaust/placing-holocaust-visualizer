# %%
import pandas as pd
import glob
from bs4 import BeautifulSoup
import os

# %%
files = glob.glob("../data/testimonies/*.html")

# %%
# List of span classes to track
classes_to_track = [
    'BUILDING', 'NPIP', 'COUNTRY', 'POPULATED_PLACE', 'DLF', 
    'SPATIAL_OBJ', 'REGION', 'ENV_FEATURES', 'INT_SPACE', 
    'RIVER', 'FOREST'
]

data = []
for file in files:
    with open(file, "r", encoding="utf-8") as f:
        html = f.read()
    soup = BeautifulSoup(html, 'html.parser')
    spans = soup.find_all('span')

    # Initialize counters and texts
    counters = {cls: 0 for cls in classes_to_track}
    texts = {cls: [] for cls in classes_to_track}

    for span in spans:
        # Skip spans with class 'sentence'
        if 'sentence' in span.get('class', []):
            continue

        for cls in span.get('class', []):
            if cls in classes_to_track:
                counters[cls] += 1
                texts[cls].append(span.text)

    # Only the filename, not the full path
    filename = os.path.basename(file)

    # Append the data for this file
    data.append({
        "file": filename,
        **counters,
        **{cls + "_texts": texts[cls] for cls in classes_to_track}
    })

# %%
df = pd.DataFrame(data)
df
# Out:
#                        file  BUILDING  NPIP  COUNTRY  POPULATED_PLACE  DLF  \
# 0    RG-50.549.01.0027.html       163    11       91              174   22
# 1       RG-50.233.0022.html       233    34      106              284   22
# 2    RG-50.549.02.0072.html       251    26       78              243   39
# 3       RG-50.030.0018.html        73    33       70              112   32
# 4       RG-50.030.0448.html       189    42       58              123   98
# ..                      ...       ...   ...      ...              ...  ...
# 882     RG-50.106.0196.html       106     3       85               58   31
# 883     RG-50.030.0349.html       127    32      111              166   57
# 884     RG-50.106.0179.html       105    24       93              134   67
# 885     RG-50.030.0575.html        75    24       58              117   28
# 886     RG-50.030.0060.html       160    27       47               78   57
#
#      SPATIAL_OBJ  REGION  ENV_FEATURES  INT_SPACE  ...  \
# 0             27      28             6         20  ...
# 1             61      34            21         15  ...
# 2             47      54             3         14  ...
# 3             23       4            46         12  ...
# 4             30      34             7         46  ...
# ..           ...     ...           ...        ...  ...
# 882           24       5             8         22  ...
# 883           89      38            15          8  ...
# 884           22       4             6         42  ...
# 885           69       0             7         25  ...
# 886           54      14             4         35  ...
#
#                                             NPIP_texts  \
# 0    [place, places, places, place, hell, side, pla...
# 1    [places, place, place, place, place, places, p...
# 2    [places, places, places, place, place, place, ...
# 3    [place, place, inside, place, places, place, p...
# 4    [place, places, outside, place, place, outside...
# ..                                                 ...
# 882                           [outside, place, inside]
# 883  [place, place, place, place, place, place, pla...
# 884  [place, place, place, place, place, outside, s...
# 885  [place, place, place, place, place, place, pla...
# 886  [outside, place, side, place, outside, outside...
#
#                                          COUNTRY_texts  \
# 0    [Poland, Romania, Hungary, Romania, Romania, R...
# 1    [America, America, America, Crimea, Russia, Cr...
# 2    [United States, country, Palestine, Israel, co...
# 3    [Poland, Poland, Poland, Israel, Poland, Polan...
# 4    [Germany, Germany, Poland, Poland, Poland, cou...
# ..                                                 ...
# 882  [Germany, Germany, Germany, Germany, Poland, c...
# 883  [Romania, Romania, America, Romania, France, G...
# 884  [Russia, Russia, Latvia, Latvia, Russia, Latvi...
# 885  [Poland, Poland, Israel, Israel, Israel, Pales...
# 886  [Czechoslovakia, Poland, Hungary, Hungary, Uni...
#
#                                  POPULATED_PLACE_texts  \
# 0    [Auschwitz, camp, city, cities, town, camp, ho...
# 1    [Leningrad, Leningrad, Smela, Moscow, Starodub...
# 2    [community,, Washington, Olney, Philadelphia, ...
# 3    [city, Lomza, Lomza, Lomza, Lomza, Lakhva, ghe...
# 4    [Hindenberg, Hindenberg, Hindenberg, city, cit...
# ..                                                 ...
# 882  [Ludwigshafen, Ludwigshafen, industrial city, ...
# 883  [Paris, Paris, Paris, Paris, Jewish community,...
# 884  [Riga, city, Livani, Livani, Subata, town, Sub...
# 885  [Warsaw, Warsaw, Paris, Warsaw, Warsaw, ghetto...
# 886  [city, Berehovo, city, cities, neighborhood, c...
#
#                                              DLF_texts  \
# 0    [window, street, yard, roof, railroads, line, ...
# 1    [blockade, beach, blockade, farm, farm, Greek ...
# 2    [window, bridge, Rivington Street, Bleeker Str...
# 3    [border, border, border, border, bridge, cemet...
# 4    [play ground, streets, windows, doors, window,...
# ..                                                 ...
# 882  [street, park, park, roof, street, street, str...
# 883  [Maginot line, Maginot line, road, road, garde...
# 884  [garden, ranch, street, Fence, wall, wall, iro...
# 885  [street, park, park, doors, street, hole, door...
# 886  [streets, streets, streets, street, back yard,...
#
#                                      SPATIAL_OBJ_texts  \
# 0    [train, ship, Saint Louis, trains, boxcars, pi...
# 1    [piano, piano, piano, car, car, car, car, car,...
# 2    [plane, plane, plane, plane, boat, aircraft, j...
# 3    [bed, beds, train, train, airplanes, table, ov...
# 4    [train, wagons, wagon, bed, bed, beds, bed, be...
# ..                                                 ...
# 882  [piano, table, piano, Steinway, bed, train, tr...
# 883  [table, tanks, airplane, cars, motorcycles, mo...
# 884  [train, train, train, train, ship, train, trai...
# 885  [pram, baby carriage, baby pram, train, trains...
# 886  [ship, beds, podium, podium, train, railroad c...
#
#                                           REGION_texts  \
# 0    [area, eastern European continent, area, area,...
# 1    [Siberia, Siberia, White Russia, Siberia, Sibe...
# 2    [Newfoundland, New Jersey, Pennsylvania, west ...
# 3      [Russian side, area, Russian side, German side]
# 4    [Eastern Germany, Eastern Poland, area, Aryan ...
# ..                                                 ...
# 882  [area, area, North Carolina, North Carolina, N...
# 883  [area, Eastern Europe, Brittany, Brittany, are...
# 884         [Baltic states, Siberia, Siberia, Siberia]
# 885                                                 []
# 886  [area, area, Pennsylvania, areas, areas, area,...
#
#                                     ENV_FEATURES_texts  \
# 0    [ground, forest, forest, mountains, forests, b...
# 1    [wood forest, wood, forest, wood, forest, fore...
# 2                               [gazebo, lake, forest]
# 3    [water, woods, trees, woods, woods, woods, woo...
# 4    [ground, forests, ground, ground, ground, wood...
# ..                                                 ...
# 882  [Alps, Atlantic, Rheingold, Rheingold, river R...
# 883  [forest, forest, forest, ground, mountain, mou...
# 884     [apple tree, tree, Viesite, woods, wood, wood]
# 885  [forest, ground, ground, river, lake, hills, m...
# 886              [mountains, mountains, trees, forest]
#
#                                        INT_SPACE_texts RIVER_texts  \
# 0    [apartment, apartment, bedroom apartment, apar...          []
# 1    [room, room, room, apartment, apartment, room,...          []
# 2    [sublet apartment, sublet apartment, apartment...          []
# 3    [floor, floor, room, room, apartment, room, fl...          []
# 4    [apartments, celler, celler, floor, space, flo...          []
# ..                                                 ...         ...
# 882  [kitchen, floor, apartment, cellars, cellars, ...          []
# 883  [balcony, apartment, room, compartments, room,...          []
# 884  [apartment, apartments, apartment, apartment, ...          []
# 885  [floor, apartment, room, cupboard, cupboard, c...          []
# 886  [room, shower, shower, shower, shower, room, f...          []
#
#     FOREST_texts
# 0             []
# 1             []
# 2             []
# 3             []
# 4             []
# ..           ...
# 882           []
# 883           []
# 884           []
# 885           []
# 886           []
#
# [887 rows x 23 columns]

# %%
span_class
# Out:
# ['BUILDING',
#  'NPIP',
#  'COUNTRY',
#  'POPULATED_PLACE',
#  'DLF',
#  'SPATIAL_OBJ',
#  'REGION',
#  'ENV_FEATURES',
#  'INT_SPACE',
#  'RIVER',
#  'FOREST']

# %%
df.to_parquet("../data/data_counts.parquet")

# %%
df2 = pd.read_csv("../data/testimony_metadata.csv")
df2.keys()
# Out:
# Index(['RG Number', 'PDF URL', 'USHMM URL', 'First Name', 'Middle Name',
#        'Last Name', 'Birth Name', 'Gender', 'Birth Date', 'Birth Year',
#        'Place of Birth', 'Country', 'Experience Group',
#        'Ghetto(s) Encyclopedia', 'Ghetto', 'Camp(s) Encyclopedia', 'Camp',
#        'Non-SS Camp  ', 'Region', 'Needs Research', 'Data Entry', 'Accession',
#        'Notes:', 'Revisit'],
#       dtype='object')

# %%
df2
# Out:
#              RG Number                                            PDF URL  \
# 0    RG-50.549.02.0033  https://collections.ushmm.org/oh_findingaids/R...
# 1    RG-50.549.02.0072  https://collections.ushmm.org/oh_findingaids/R...
# 2    RG-50.549.02.0035  https://collections.ushmm.org/oh_findingaids/R...
# 3       RG-50.471.0015  https://collections.ushmm.org/oh_findingaids/R...
# 4       RG-50.030.0585  https://collections.ushmm.org/oh_findingaids/R...
# ..                 ...                                                ...
# 972  RG-50.549.02.0073  https://collections.ushmm.org/oh_findingaids/R...
# 973     RG-50.030.0137  https://collections.ushmm.org/oh_findingaids/R...
# 974     RG-50.030.0058  https://collections.ushmm.org/oh_findingaids/R...
# 975  RG-50.549.02.0078  https://collections.ushmm.org/oh_findingaids/R...
# 976  RG-50.549.02.0038  https://collections.ushmm.org/oh_findingaids/R...
#
#                                              USHMM URL First Name  \
# 0    https://collections.ushmm.org/search/catalog/i...      Hetty
# 1    https://collections.ushmm.org/search/catalog/i...    Emanuel
# 2    https://collections.ushmm.org/search/catalog/i...     Judith
# 3    https://collections.ushmm.org/search/catalog/i...     Esther
# 4    https://collections.ushmm.org/search/catalog/i...     Eugene
# ..                                                 ...        ...
# 972  https://collections.ushmm.org/search/catalog/i...      Flory
# 973  https://collections.ushmm.org/search/catalog/i...  Cornelius
# 974  https://collections.ushmm.org/search/catalog/i...      Isaac
# 975  https://collections.ushmm.org/search/catalog/i...      Lucie
# 976  https://collections.ushmm.org/search/catalog/i...      Isaac
#
#      Middle Name  Last Name      Birth Name Gender  Birth Date  Birth Year  \
# 0    d'Ancona de     Leeuwe  Hetty D'Ancona      F  1930-05-01      1930.0
# 1            NaN     Mandel             NaN      M         NaN      1936.0
# 2            NaN     Meisel             NaN      F         NaN      1929.0
# 3            NaN      Lurie             NaN      F         NaN         NaN
# 4            NaN     Miller             NaN      M  1923-10-16      1923.0
# ..           ...        ...             ...    ...         ...         ...
# 972          NaN     Jagoda             NaN      F  1923-12-21      1923.0
# 973          NaN       Loen             NaN      M  1922-05-02      1922.0
# 974          NaN      Danon             NaN      M         NaN      1929.0
# 975          NaN  Rosenberg             NaN      F         NaN      1921.0
# 976          NaN      Danon             NaN      M  1929-06-24      1929.0
#
#      ...  Ghetto Camp(s) Encyclopedia Camp Non-SS Camp   Region  \
# 0    ...     NaN                  NaN  NaN           NaN    NaN
# 1    ...     NaN                  NaN  NaN           NaN    NaN
# 2    ...  Kaunas                  NaN  NaN           NaN    NaN
# 3    ...     NaN                  NaN  NaN           NaN    NaN
# 4    ...    Lodz     Auschwitz,Dachau  NaN           NaN    NaN
# ..   ...     ...                  ...  ...           ...    ...
# 972  ...     NaN                  NaN  NaN           NaN    NaN
# 973  ...     NaN                  NaN  NaN           NaN    NaN
# 974  ...     NaN                  NaN  NaN           NaN    NaN
# 975  ...     NaN                  NaN  NaN           NaN    NaN
# 976  ...     NaN                  NaN  NaN           NaN    NaN
#
#     Needs Research Data Entry       Accession  \
# 0              NaN         CL     1999.A.0293
# 1          checked         GG        2003.205
# 2          checked         GG     1999.A.0024
# 3              NaN         CL  1998.A.0119.15
# 4          checked         GG        2010.249
# ..             ...        ...             ...
# 972            NaN         GG         2004.48
# 973            NaN         CL      1990.437.1
# 974            NaN         GG             NaN
# 975        checked         CL        2004.214
# 976            NaN         CL     1999.A.0038
#
#                                                 Notes:  Revisit
# 0                                                  NaN      NaN
# 1                                  Follow-up interview      NaN
# 2    This is a follow-up interview to one already d...  checked
# 3                                                  NaN      NaN
# 4                                                  NaN      NaN
# ..                                                 ...      ...
# 972                                          Follow-up  checked
# 973                                                NaN      NaN
# 974                                                NaN      NaN
# 975       Not a survivor, volunteered for the museum?       NaN
# 976                                                NaN      NaN
#
# [977 rows x 24 columns]

# %%
# Remove the '.html' extension from the 'file' column in df
df['file'] = df['file'].str.replace('.html', '', regex=False)

# Perform the merge
df3 = pd.merge(df, df2, left_on='file', right_on='RG Number', how='inner')
df3
# Out:
#                   file  BUILDING  NPIP  COUNTRY  POPULATED_PLACE  DLF  \
# 0    RG-50.549.01.0027       163    11       91              174   22
# 1       RG-50.233.0022       233    34      106              284   22
# 2    RG-50.549.02.0072       251    26       78              243   39
# 3       RG-50.030.0018        73    33       70              112   32
# 4       RG-50.030.0448       189    42       58              123   98
# ..                 ...       ...   ...      ...              ...  ...
# 882     RG-50.106.0196       106     3       85               58   31
# 883     RG-50.030.0349       127    32      111              166   57
# 884     RG-50.106.0179       105    24       93              134   67
# 885     RG-50.030.0575        75    24       58              117   28
# 886     RG-50.030.0060       160    27       47               78   57
#
#      SPATIAL_OBJ  REGION  ENV_FEATURES  INT_SPACE  ...  Ghetto  \
# 0             27      28             6         20  ...     NaN
# 1             61      34            21         15  ...     NaN
# 2             47      54             3         14  ...     NaN
# 3             23       4            46         12  ...     NaN
# 4             30      34             7         46  ...     NaN
# ..           ...     ...           ...        ...  ...     ...
# 882           24       5             8         22  ...     NaN
# 883           89      38            15          8  ...     NaN
# 884           22       4             6         42  ...     NaN
# 885           69       0             7         25  ...     NaN
# 886           54      14             4         35  ...     NaN
#
#          Camp(s) Encyclopedia Camp Non-SS Camp   Region Needs Research  \
# 0                   Auschwitz  NaN           NaN   West            NaN
# 1                         NaN  NaN           NaN    NaN            NaN
# 2                         NaN  NaN           NaN    NaN        checked
# 3                         NaN  NaN           NaN    NaN            NaN
# 4                         NaN  NaN           NaN   East            NaN
# ..                        ...  ...           ...    ...            ...
# 882                       NaN  NaN           NaN    NaN            NaN
# 883                       NaN  NaN           NaN    NaN            NaN
# 884                       NaN  NaN           NaN    NaN            NaN
# 885  Bergen-Belsen,Buchenwald  NaN           NaN   West            NaN
# 886                       NaN  NaN           NaN    NaN            NaN
#
#     Data Entry       Accession  \
# 0           CL             NaN
# 1           GG  1992.A.0125.22
# 2           GG        2003.205
# 3           GG             NaN
# 4           CL     1996.A.0528
# ..         ...             ...
# 882         GG         2012.32
# 883         CL             NaN
# 884         CL         2010.23
# 885         CL        2010.143
# 886         GG      1990.388.1
#
#                                                 Notes:  Revisit
# 0                                                  NaN      NaN
# 1                                                  NaN      NaN
# 2                                  Follow-up interview      NaN
# 3                                                  NaN      NaN
# 4                  Hid in farms after escaping Buczacz      NaN
# ..                                                 ...      ...
# 882                                                NaN      NaN
# 883                                                NaN      NaN
# 884  being forced to live in the ghetto in Riga, La...  checked
# 885                                                NaN      NaN
# 886                                                NaN      NaN
#
# [887 rows x 47 columns]

# %%
df3.keys()
# Out:
# Index(['file', 'BUILDING', 'NPIP', 'COUNTRY', 'POPULATED_PLACE', 'DLF',
#        'SPATIAL_OBJ', 'REGION', 'ENV_FEATURES', 'INT_SPACE', 'RIVER', 'FOREST',
#        'BUILDING_texts', 'NPIP_texts', 'COUNTRY_texts',
#        'POPULATED_PLACE_texts', 'DLF_texts', 'SPATIAL_OBJ_texts',
#        'REGION_texts', 'ENV_FEATURES_texts', 'INT_SPACE_texts', 'RIVER_texts',
#        'FOREST_texts', 'RG Number', 'PDF URL', 'USHMM URL', 'First Name',
#        'Middle Name', 'Last Name', 'Birth Name', 'Gender', 'Birth Date',
#        'Birth Year', 'Place of Birth', 'Country', 'Experience Group',
#        'Ghetto(s) Encyclopedia', 'Ghetto', 'Camp(s) Encyclopedia', 'Camp',
#        'Non-SS Camp  ', 'Region', 'Needs Research', 'Data Entry', 'Accession',
#        'Notes:', 'Revisit'],
#       dtype='object')

# %%
df3.to_parquet("../data/data_counts.parquet")
